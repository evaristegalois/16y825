# %%
import pandas as pd

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# %%
cwd='/content/drive/MyDrive/Colab Notebooks'

# %%
from PIL import Image
from IPython.display import display

# %%
# careful about changes that need to be made:
#    (1) update lukm_marks.csv
#    (2) update ast and course
#    (3) update Canvas exported filename
#    (4) update the column titles for the appropriate assessment

# %%
# orange dot next to grade in canvas means grade is not posted yet
# just click on three dots in column header to post the grade
ast="zcfw"
course=782

# %%
studentsF= students[students['course'] == course]

# %%
# you may get a warning here which you can ignore
studentsF['sdc'] = studentsF['sdc'].astype('int64')
# Out:
# <ipython-input-91-020d8c61b01d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   studentsF['sdc'] = studentsF['sdc'].astype('int64')

# %%
marks=pd.read_csv(cwd + "/inputcsv/lukm_marks.csv")

# %%
marksF= marks[marks['ast'] == ast]

# %%
# create no submission assignment and export Current Gradebook View then past exported filename here
canvasExport=pd.read_csv(cwd + "/inputcsv/2023-05-01T1304_Grades-PHIL_375A_901_2022W2.csv")

# %%
# print(studentsF.dtypes)

# %%
# print(marksF.dtypes)

# %%
merged=pd.merge(marksF,studentsF, how='inner', on='sdc')

# %%
# getting rid of the silly floats that should be strings
canvasExport['Student Number'] = canvasExport['Student Number'].apply(lambda x: str(int(x)) if not np.isnan(x) else "NaN")

# %%
a2 = pd.merge(canvasExport, merged, how='inner', left_on='Student Number', right_on='sno')

# %%
# pd.set_option('display.max_rows', None)
# pd.set_option('display.max_columns', None)
# a2

# %%
list(a2)

# %%
# choose the appropriate column name WITH the corresponding seven-digit identifier
a2['Essay 2 (1522349)']=a2['mark']

# %%
a2.drop(['ast','sdc','mark','course','sno','password','ln','fn'], axis=1, inplace=True)

# %%
# getting rid of the silly floats that should be strings
a2['Lecture'] = a2['Lecture'].apply(lambda x: str(int(x)) if not np.isnan(x) else "NaN")
a2['SIS User ID'] = a2['SIS User ID'].apply(lambda x: str(int(x)) if not np.isnan(x) else "NaN")
a2['ID'] = a2['ID'].apply(lambda x: str(int(x)) if not np.isnan(x) else "NaN")

# %%
a2.to_csv(cwd + f"/outputcsv/canvas-{ast}.csv", index = False, header = True)

# %%
a2
