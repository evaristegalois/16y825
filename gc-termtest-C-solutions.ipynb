# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# %%
cwd='/content/drive/MyDrive/Colab Notebooks'

# %%
from PIL import Image
from IPython.display import display

# %% [markdown]
# <h2>Term Test C Solutions</h2>

# %% [markdown]
# <h3>Question 1</h3>

# %% [markdown]
# Find the volume of the solid generated when the region
# between the graphs of the equations
# \begin{align*}
#   f(x)&=\frac{1}{2}+x^2\\
#   g(x)&=x
# \end{align*}
# over the interval $[0,2]$ is revolved about the $x$-axis.

# %%
file = cwd + "/diagrams/sapwnioh.png"
img = Image.open(file)

percentage = 50 # 50% reduction in size
new_size = tuple([int(x * percentage / 100) for x in img.size])
img = img.resize(new_size)

display(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=354x199 at 0x7F76CA774310>

# %%
# outdated way of displaying images here -- see above for a much better way
from IPython.display import Image
Image(url='https://drive.google.com/uc?id=1Qhc7H73kKg-Okd860k9lEYj8l9uZGSIG')
# Out:
# <img src="https://drive.google.com/uc?id=1Qhc7H73kKg-Okd860k9lEYj8l9uZGSIG"/>

# %%
/(*(69,pi),10)
# Out:
# 21.676989309769574

# %% [markdown]
# <h3>Question 2</h3>

# %% [markdown]
# Find the arc length of
# \begin{equation}
#   \label{eq:dqnkvatt}
#   y=x^{\frac{3}{2}},1\leq{}x\leq{}4\notag
# \end{equation}

# %% [markdown]
# \begin{equation}
#   \label{eq:yemaezov}
#     L=\int_{a}^{b}\sqrt{1+\left(f'(x)\right)^{2}}\,dx
# \end{equation}

# %%
Image(url='https://drive.google.com/uc?id=1QAXBH-USwoT7qsDzKPlUdQGrx6HnfGaZ')
# Out:
# <img src="https://drive.google.com/uc?id=1QAXBH-USwoT7qsDzKPlUdQGrx6HnfGaZ"/>

# %%
L1=/(-(*(80,sqrt(10)),*(13,sqrt(13))),27)
# Out:
# 7.633705416016242

# %%
sqrt(+(^(7,2),^(3,2))) # linear approximation
# Out:
# 7.615773105863909

# %% [markdown]
# <h3>Question 3</h3>

# %% [markdown]
# <font color="red">-1/3 because no chain rule subtract 2 points</font>

# %% [markdown]
# Evaluate
# \begin{equation}
#   \label{eq:nhyhlaut}
#   \int_0^{\frac{\pi}{2}}\sin^23\theta\cos{}3\theta\,d\theta\notag
# \end{equation}
# Hint: substitute $u=\sin{}3\theta$.

# %% [markdown]
# $$
# \int\sin^23\theta\cos{}3\theta\,d\theta=\frac{1}{3}\int{}u^2\,du=\frac{1}{9}\sin^33\theta+C
# $$

# %%
F(x)=*(/(1,9),^(sin(*(3,x)),3))

# %%
F(pi/2)-F(0)
# Out:
# -0.1111111111111111

# %% [markdown]
# <h3>Question 4</h3>

# %% [markdown]
# Find the area of the surface generated by revolving the
# curve
# \begin{equation}
#   \label{eq:jqyzqykz}
#   y=\sqrt{x^2+2},0\leq{}x\leq\sqrt{2}\notag
# \end{equation}
# about the $x$-axis. You may need the integral
# \begin{equation}
#   \label{eq:ycdmkwdt}
#   \int\sqrt{x^2+1}\,dx=\frac{x}{2}\sqrt{x^2+1}+\frac{1}{2}\ln\left(x+\sqrt{x^2+1}\right)+C\notag
# \end{equation}

# %%
file = cwd + "/diagrams/ajlupxjo-solution.png"
img = Image.open(file)

percentage = 50 # 50% reduction in size
new_size = tuple([int(x * percentage / 100) for x in img.size])
img = img.resize(new_size)

display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=464x331 at 0x7F76CA76AFB0>

# %%
S1=+(*(2,pi,sqrt(3)),*(sqrt(2),pi,log(+(sqrt(2),sqrt(3)))))
# Out:
# 15.975298961198934

# %%
using QuadGK

# %%
integral,err=quadgk(x->*(2,pi,sqrt(+(2,*(2,^(x,2))))),0,sqrt(2),rtol=1e-8)
# Out:
# (15.975298961198932, 2.677069232959184e-9)

# %% [markdown]
# <h3>Question 5</h3>

# %% [markdown]
# Find
# \begin{equation}
#     \int\frac{1}{\left(4x^2+9\right)^2}\,dx\notag
# \end{equation}
# Hint: use the substitution $2x=3\tan{}u$.

# %%
file = cwd + "/diagrams/occlkrmx1.png"
img = Image.open(file)

percentage = 50 # 50% reduction in size
new_size = tuple([int(x * percentage / 100) for x in img.size])
img = img.resize(new_size)

display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=614x499 at 0x7F76EB68F160>

# %%
from IPython.display import Image
Image(url='https://drive.google.com/uc?id=1W8hyGrA20V9LauOlmCmCoEPJRZsVuGpZ')
# Out:
# <img src="https://drive.google.com/uc?id=1W8hyGrA20V9LauOlmCmCoEPJRZsVuGpZ"/>

# %% [markdown]
# <h3>Question 6</h3>

# %% [markdown]
# Use cylindrical shells to find the volume of the solid
# that results when the shaded region is revolved about the $y$-axis.
# The following curves are the boundaries of the region:
# \begin{equation}
#   \label{eq:ohwoodee}
#   y=x^{2}\qquad{}x=2\qquad{}x=3\qquad{}y=0\notag
# \end{equation}

# %%
file = cwd + "/diagrams/iawazahf.png"
img = Image.open(file)

percentage = 50 # 50% reduction in size
new_size = tuple([int(x * percentage / 100) for x in img.size])
img = img.resize(new_size)

display(img)
# Out:
# <PIL.Image.Image image mode=RGBA size=351x355 at 0x7F76CA774520>

# %% [markdown]
# $$
# V=2\pi\int{}xf(x)\,dx\
# $$

# %% [markdown]
# $$
# V=2\pi\int_{2}^{3}x^{3}\,dx=2\pi\left[\frac{x^{4}}{4}\right]_{2}^{3}=\frac{65}{2}\pi
# $$

# %%
*(/(65,2),pi)
# Out:
# 102.10176124166827

# %% [markdown]
# <h3>Question 7</h3>

# %% [markdown]
# Choose one of the following three integrals to solve. If
# you choose (3), you can only get 4 out of 5 points.
# \begin{equation}
#   \label{eq:rcemebce}
#   \int_{\sqrt{3}-2}^{3\sqrt{3}-2}\frac{18}{x^2+4x+13}\,dx
# \end{equation}

# %% [markdown]
# $$
# \int_{\sqrt{3}-2}^{3\sqrt{3}-2}\frac{18}{x^2+4x+13}\,dx=\int_{\sqrt{3}-2}^{3\sqrt{3}-2}\frac{18}{(x+2)^2+9}\,dx=\int_{\Box}^{\Box}\frac{18}{u^2+9}\,du=\frac{18}{3}\arctan\sqrt{3}-\frac{18}{3}\arctan\frac{1}{\sqrt{3}}=\frac{18}{3}\left(\frac{\pi}{3}-\frac{\pi}{6}\right)=\pi
# $$

# %%
using QuadGK

# %%
integral,err=quadgk(x->/(18,+(^(x,2),*(4,x),13)),sqrt(3)-2,3*sqrt(3)-2,rtol=1e-8)
# Out:
# (3.141592653589794, 5.200391228754597e-10)

# %% [markdown]
# \begin{equation}
#   \label{eq:lokvrfcz}
#   \int\frac{-3x^3+9x^2-9x+7}{-x^2+3x-2}\,dx
# \end{equation}

# %%
from IPython.display import Image
Image(url='https://drive.google.com/uc?id=1H-nxsj8I6cKLrLW1LD4YCfjH2kdjZU12')
# Out:
# <img src="https://drive.google.com/uc?id=1H-nxsj8I6cKLrLW1LD4YCfjH2kdjZU12"/>

# %%
from IPython.display import Image
Image(url='https://drive.google.com/uc?id=17BIy0vDJkdrkx1zC0fSuvGRWH1ZbD-HA')
# Out:
# <img src="https://drive.google.com/uc?id=17BIy0vDJkdrkx1zC0fSuvGRWH1ZbD-HA"/>

# %% [markdown]
# \begin{equation}
#   \label{eq:jvrmhsgf}
#   \int\frac{5x}{x^2-x-2}\,dx
# \end{equation}

# %%
from IPython.display import Image
Image(url='https://drive.google.com/uc?id=16cge1ygVsYIpCt14V1EuPTB61rH-9z3S')
# Out:
# <img src="https://drive.google.com/uc?id=16cge1ygVsYIpCt14V1EuPTB61rH-9z3S"/>

# %% [markdown]
# <h3>Question 8</h3>

# %% [markdown]
# Evaluate
# \begin{equation}
#   \label{eq:phooyeit}
#   \int_{\frac{1}{3}}^{\frac{\pi+4}{12}}\sin^{2}\left(3x-1\right)\,dx\notag
# \end{equation}

# %%
file = cwd + "/diagrams/bhippwin.png"
img = Image.open(file)

percentage = 50 # 50% reduction in size
new_size = tuple([int(x * percentage / 100) for x in img.size])
img = img.resize(new_size)

display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=749x468 at 0x7F76CA76BC40>

# %%
/(-(pi,2),24)
# Out:
# 0.04756636056624138

# %%
integral,err=quadgk(x->^(sin(-(*(3,x),1)),2),/(1,3),/(+(pi,4),12),rtol=1e-8)
# Out:
# (0.04756636056624137, 1.3877787807814457e-17)
