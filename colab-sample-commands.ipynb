# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
a2=pd.read_csv("./inputcsv/allauthors.csv")

# %%
from IPython.display import Image
Image(url='https://drive.google.com/uc?id=1Sa6-DvKl-jKNv03Va8G4VyUMGyTzHrK8')
# Out:
# <img src="https://drive.google.com/uc?id=1Sa6-DvKl-jKNv03Va8G4VyUMGyTzHrK8"/>

# %%
a1=1

# %%
a2=2

# %%
a3=3

# %% [markdown]
# ![](./diagrams/bale.png)
